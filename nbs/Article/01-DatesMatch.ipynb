# %% [markdown]
# # Article - Issue Statement Figure

# %% [markdown]
# This first figure of the article has as objective to demonstrate the issues in the Raster product that are possible to be stated visually.

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

from swot_toolkit.analysis import plot_inner_swath_analysis
from swot_toolkit.opera import plot_opera_array
from swot_toolkit.pipe2 import open_output_dir
from swot_toolkit.pipe4 import create_swot_mosaic, open_datasets, plot_ref_mask, plot_s2_rgb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Figure 1

# %%
REGION = "Rio_Branco"
OUTPUT_DIR = "/data/swot/output"
DATE = "2025-09-07"

# %%
base_dir, aoi, s2_id = open_output_dir(REGION, DATE)
datasets = open_datasets(REGION, DATE)

# %%
swot_mask, patches, no_data_masks = create_swot_mosaic(
    REGION,
    DATE,
    dst_crs=datasets["ref_mask"].rio.crs,
    exclude_flags=None,
    exclude_no_data=False,
)

# %%
fig = plt.figure(figsize=(14, 16))

# Create a grid layout
gs = fig.add_gridspec(3, 2, height_ratios=[1, 1, 0.05], hspace=0.3, wspace=0.2)

# Top row
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

# Bottom row
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])

# Colorbar axis
cbar_ax1 = fig.add_subplot(gs[2, 0])
cbar_ax2 = fig.add_subplot(gs[2, 1])

# Plot data
plot_s2_rgb(datasets["s2_img"], ax=ax1)
ax1.set_aspect("equal")
ax1.set_title(f"Sentinel-2 RGB {DATE}")

plot_ref_mask(datasets["ref_mask"], down_factor=2, ax=ax2, add_colorbar=False)
ax2.set_aspect("equal")
ax2.set_title("Reference Mask")

# Plot SWOT patches
for i, patch in enumerate(patches[::-1]):
    ax = ax3 if i == 0 else ax4
    patch = patch.where(patch["water_frac"] > 0)
    im = patch["water_frac"].plot(ax=ax, cmap="Blues", vmin=0, vmax=1, add_colorbar=False)
    ax.set_aspect("equal")
    ax.set_title(f"SWOT Water Fraction - {patch.attrs['time_coverage_start'][:10]}")

# Add shared colorbar
cbar1 = plt.colorbar(im, cax=cbar_ax1, orientation="horizontal")
cbar1.set_label("Water Fraction", fontsize=12)

cbar2 = plt.colorbar(im, cax=cbar_ax2, orientation="horizontal")
cbar2.set_label("Water Fraction", fontsize=12)

# %% [markdown]
# ## Figure 2

# %%
import earthaccess
import geopandas as gpd
import rioxarray as xrio

from swot_toolkit.analysis import plot_footprint, plot_nadir_line, plot_water_fraction

# %%
# First, open the output directory for this region and date
base_dir = Path(OUTPUT_DIR) / REGION
mosaic_df = pd.read_parquet(base_dir / "dfs/swot_raster_results.parquet")
mosaic_items = mosaic_df.loc[DATE]

# %%
# Get the files
mosaic_files = earthaccess.download(
    mosaic_items["url"].to_list(),
    local_path="/data/swot/download",
    pqdm_kwargs={"disable": True},
)

# %%
aoi_gdf = gpd.GeoDataFrame(geometry=[aoi], crs="EPSG:4326")

# %%
ds
# Out:
# <xarray.Dataset> Size: 414MB
# Dimensions:                  (x: 1453, y: 1453)
# Coordinates:
#     band                     int64 8B 1
#   * x                        (x) float64 12kB 5.881e+05 5.882e+05 ... 7.333e+05
#   * y                        (y) float64 12kB 1.001e+07 1.001e+07 ... 9.864e+06
#     crs                      int64 8B 0
# Data variables: (12/38)
#     longitude                (y, x) float64 17MB ...
#     water_area_uncert        (y, x) float32 8MB ...
#     water_frac               (y, x) float32 8MB ...
#     water_frac_uncert        (y, x) float32 8MB ...
#     sig0                     (y, x) float32 8MB ...
#     sig0_qual                (y, x) float32 8MB ...
#     ...                       ...
#     wse_qual                 (y, x) float32 8MB ...
#     wse_qual_bitwise         (y, x) float64 17MB ...
#     wse_uncert               (y, x) float32 8MB ...
#     water_area               (y, x) float32 8MB ...
#     water_area_qual          (y, x) float32 8MB ...
#     water_area_qual_bitwise  (y, x) float64 17MB ...
# Attributes: (12/49)
#     contact:                       podaac@podaac.jpl.nasa.gov
#     Conventions:                   CF-1.7
#     coordinate_reference_system:   Universal Transverse Mercator
#     crid:                          PID0
#     cycle_number:                  38
#     descriptor_string:             100m_UTM20M_N_x_x_x
#     ...                            ...
#     xref_param_l2_hr_raster_file:  SWOT_Param_L2_HR_Raster_20000101T000000_21...
#     xref_reforbittrack_files:      SWOT_RefOrbitTrackTileBoundary_Nom_2000010...
#     x_max:                         733300
#     x_min:                         588100
#     y_max:                         10009300
#     y_min:                         9864100

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 7))

for ax, file in zip(axs.reshape(-1), mosaic_files[::-1], strict=True):
    ds = xrio.open_rasterio(file, mask_and_scale=True).squeeze()

    water_frac = ds["water_frac"].sel(x=slice(None, None, 2), y=slice(None, None, 2)).squeeze()
    water_frac.plot.imshow(ax=ax, vmin=0, vmax=1, add_colorbar=False, cmap="Blues")

    nadir_handle = plot_nadir_line(ds, ax)
    footprint_handle = plot_footprint(ds, ax)

    aoi_gdf.to_crs(ds.rio.crs).plot(ax=ax, facecolor="none", edgecolor="darkgreen", linewidth=2)

    title = "SWOT Scene - "
    title += str(ds.attrs["pass_number"]) + "/" + str(ds.attrs["scene_number"])
    title += "F (Pass/Scene)"
    ax.set_title(title)

# %%
band
# Out:
# '/data/swot/download/SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_038_270_078F_20250909T202640_20250909T202701_PID0_01.nc'

# %%
ds
# Out:
# <xarray.Dataset> Size: 414MB
# Dimensions:                  (x: 1453, y: 1453)
# Coordinates:
#     band                     int64 8B 1
#   * x                        (x) float64 12kB 5.4e+05 5.401e+05 ... 6.852e+05
#   * y                        (y) float64 12kB 1.001e+07 1.001e+07 ... 9.864e+06
#     crs                      int64 8B 0
# Data variables: (12/38)
#     longitude                (y, x) float64 17MB ...
#     water_area_uncert        (y, x) float32 8MB ...
#     water_frac               (y, x) float32 8MB ...
#     water_frac_uncert        (y, x) float32 8MB ...
#     sig0                     (y, x) float32 8MB ...
#     sig0_qual                (y, x) float32 8MB ...
#     ...                       ...
#     wse_qual                 (y, x) float32 8MB ...
#     wse_qual_bitwise         (y, x) float64 17MB ...
#     wse_uncert               (y, x) float32 8MB ...
#     water_area               (y, x) float32 8MB ...
#     water_area_qual          (y, x) float32 8MB ...
#     water_area_qual_bitwise  (y, x) float64 17MB ...
# Attributes: (12/49)
#     contact:                       podaac@podaac.jpl.nasa.gov
#     Conventions:                   CF-1.7
#     coordinate_reference_system:   Universal Transverse Mercator
#     crid:                          PID0
#     cycle_number:                  38
#     descriptor_string:             100m_UTM20M_N_x_x_x
#     ...                            ...
#     xref_param_l2_hr_raster_file:  SWOT_Param_L2_HR_Raster_20000101T000000_21...
#     xref_reforbittrack_files:      SWOT_RefOrbitTrackTileBoundary_Nom_2000010...
#     x_max:                         685200
#     x_min:                         540000
#     y_max:                         10009300
#     y_min:                         9864100

# %%
# First, open the output directory for this region and date
base_dir = Path(OUTPUT_DIR) / REGION
mosaic_df = pd.read_parquet(base_dir / "dfs/swot_raster_results.parquet")
mosaic_dates = mosaic_df.index.get_level_values("mosaic_date").unique()
mosaic_dates
# Out:
# DatetimeIndex(['2024-01-11', '2024-01-31', '2024-02-21', '2024-03-13',
#                '2024-04-03', '2024-04-24', '2024-06-05', '2024-06-25',
#                '2024-07-16', '2024-08-06', '2024-08-27', '2024-09-17',
#                '2024-10-08', '2024-10-29', '2024-11-19', '2025-01-20',
#                '2025-02-10', '2025-03-03', '2025-03-24', '2025-04-14',
#                '2025-05-04', '2025-05-25', '2025-06-15', '2025-07-06',
#                '2025-07-27', '2025-08-17', '2025-09-07'],
#               dtype='datetime64[ns]', name='mosaic_date', freq=None)

# %%
figs = plot_inner_swath_analysis(REGION, DATE)

# %%
figs[0]

# %%
aoi_path = Path("/data/swot/AOIs/") / f"{REGION}.kml"
output_dir = prepare_aoi_dataframes(aoi_path, DATE_RANGE, OUTPUT_DIR)
# Out:
# Output directory created at: /data/swot/output_article/Rio_Branco
# Searching for Sentinel-2 scenes intersecting the AOI...
# S2 tile not provided. Guessing the best tile...
# Tile 20MNE has 5631010 null values.
# Tile 20MPE has 4834296 null values.
# Best tile is 20MPE.
# Assessing clouds in Sentinel-2 scenes...
#   0%|          | 0/280 [00:00<?, ?it/s]
# Searching for OPERA satellite data intersecting the AOI...
# Found 222 OPERA satellite overpasses intersecting the AOI.
# Searching for SWOT Raster_100 data intersecting the AOI...
# Creating SWOT mosaics...
#   0%|          | 0/27 [00:00<?, ?it/s]
# Saving dataframes to /data/swot/output_article/Rio_Branco/dfs...

# %% [markdown]
# ## Analyze results

# %%
from pathlib import Path

import pandas as pd

from swot_toolkit.kml import read_kml_geometry
from swot_toolkit.pipe1 import generate_s2_figs_from_mosaic

# %%
output_dir = Path(OUTPUT_DIR) / REGION
output_dir
# Out:
# PosixPath('/data/swot/output_article/Rio_Branco')

# %%
# Open the matches between S2 and SWOT
matches = pd.read_parquet(output_dir / "dfs/swot_s2_matches.parquet")
matches.sort_values("valid_pxls", ascending=False).iloc[:10]
# Out:
#                         date                datetime   tile  valid_pxls OPERA
# swot_mosaic_date
# 2024-04-03        2024-03-30 2024-03-30 14:27:11.024  20MPE    0.986592   S2A
# 2024-02-21        2024-02-19 2024-02-19 14:27:11.024  20MPE    0.985682   S2A
# 2024-08-27        2024-08-22 2024-08-22 14:27:09.024  20MPE    0.959455   S2B
# 2025-09-07        2025-09-11 2025-09-11 14:27:31.025  20MPE    0.935522   S2C
# 2025-09-17        2025-09-21 2025-09-21 14:27:31.025  20MPE    0.933603   S2C
# 2025-04-14        2025-04-14 2025-04-14 14:28:11.025  20MPE    0.926655   S2C
# 2024-01-31        2024-01-30 2024-01-30 14:27:11.024  20MPE    0.904537   S2A
# 2024-02-21        2024-02-24 2024-02-24 14:27:09.024  20MPE    0.895677   S2B
# 2025-07-27        2025-07-23 2025-07-23 14:28:11.025  20MPE    0.835962   S2C
# 2024-09-17        2024-09-21 2024-09-21 14:27:09.024  20MPE    0.829485   S2B

# %% [markdown]
# ### Choose a mosaic date to check the S2 items (figs generated in output dir)

# %%
swot_df = pd.read_parquet(output_dir / "dfs/swot_raster_results.parquet")
swot_df
# Out:
#                       cycle_id pass_id tile_id         date_str     vers  \
# mosaic_date tile_name
# 2024-01-11  117_077F       009     117    077F  20240108T072742  PIC0_01
#             270_078F       009     270    078F  20240113T183922  PIC0_01
# 2024-01-31  117_077F       010     117    077F  20240129T041248  PIC0_01
#             270_078F       010     270    078F  20240203T152428  PIC0_01
# 2024-02-21  117_077F       011     117    077F  20240219T005753  PIC0_01
#             270_078F       011     270    078F  20240224T120933  PIC0_01
# 2024-03-13  117_077F       012     117    077F  20240310T214256  PIC0_01
#             270_078F       012     270    078F  20240316T085435  PIC0_01
# 2024-04-03  117_077F       013     117    077F  20240331T182801  PIC0_01
#             270_078F       013     270    078F  20240406T053940  PIC0_01
# 2024-04-24  117_077F       014     117    077F  20240421T151307  PIC0_02
#             270_078F       014     270    078F  20240427T022446  PIC0_01
# 2024-06-05  117_077F       016     117    077F  20240602T084316  PIC0_01
#             270_078F       016     270    078F  20240607T195455  PIC0_01
# 2024-06-25  117_077F       017     117    077F  20240623T052820  PIC0_01
#             270_078F       017     270    078F  20240628T163959  PIC0_01
# 2024-07-16  117_077F       018     117    077F  20240714T021324  PIC0_01
#             270_078F       018     270    078F  20240719T132504  PIC0_03
# 2024-08-06  117_077F       019     117    077F  20240803T225828  PIC0_01
#             270_078F       019     270    078F  20240809T101009  PIC0_01
# 2024-08-27  117_077F       020     117    077F  20240824T194332  PIC0_02
#             270_078F       020     270    078F  20240830T065513  PIC0_01
# 2024-09-17  117_077F       021     117    077F  20240914T162838  PIC0_01
#             270_078F       021     270    078F  20240920T034020  PIC0_01
# 2024-10-08  117_077F       022     117    077F  20241005T131347  PIC0_01
#             270_078F       022     270    078F  20241011T002525  PIC0_03
# 2024-10-29  117_077F       023     117    077F  20241026T095850  PIC2_01
#             270_078F       023     270    078F  20241031T211029  PIC2_02
# 2024-11-19  117_077F       024     117    077F  20241116T064354  PIC2_01
#             270_078F       024     270    078F  20241121T175535  PIC2_01
# 2025-01-20  117_077F       027     117    077F  20250117T205908  PIC2_01
#             270_078F       027     270    078F  20250123T081048  PIC2_01
# 2025-02-10  117_077F       028     117    077F  20250207T174411  PIC2_01
#             270_078F       028     270    078F  20250213T045551  PIC2_01
# 2025-03-03  117_077F       029     117    077F  20250228T142917  PIC2_01
#             270_078F       029     270    078F  20250306T014056  PIC2_01
# 2025-03-24  117_077F       030     117    077F  20250321T111422  PIC2_01
#             270_078F       030     270    078F  20250326T222601  PIC2_01
# 2025-04-14  117_077F       031     117    077F  20250411T075926  PIC2_01
#             270_078F       031     270    078F  20250416T191106  PIC2_01
# 2025-05-15  117_077F       033     117    077F  20250523T012936  PID0_01
#             270_078F       032     270    078F  20250507T155609  PID0_03
# 2025-06-15  117_077F       034     117    077F  20250612T221440  PID0_01
#             270_078F       034     270    078F  20250618T092619  PID0_01
# 2025-07-06  117_077F       035     117    077F  20250703T185947  PID0_01
#             270_078F       035     270    078F  20250709T061127  PID0_01
# 2025-07-27  117_077F       036     117    077F  20250724T154452  PID0_01
#             270_078F       036     270    078F  20250730T025631  PID0_01
# 2025-08-17  117_077F       037     117    077F  20250814T122956  PID0_01
#             270_078F       037     270    078F  20250819T234136  PID0_01
# 2025-09-07  117_077F       038     117    077F  20250904T091500  PID0_01
#             270_078F       038     270    078F  20250909T202640  PID0_01
# 2025-09-17  117_077F       039     117    077F  20250925T060003  PID0_01
#             270_078F       038     270    078F  20250909T202640  PID0_01
#
#                                  datetime        date  \
# mosaic_date tile_name
# 2024-01-11  117_077F  2024-01-08 07:27:42  2024-01-08
#             270_078F  2024-01-13 18:39:22  2024-01-13
# 2024-01-31  117_077F  2024-01-29 04:12:48  2024-01-29
#             270_078F  2024-02-03 15:24:28  2024-02-03
# 2024-02-21  117_077F  2024-02-19 00:57:53  2024-02-19
#             270_078F  2024-02-24 12:09:33  2024-02-24
# 2024-03-13  117_077F  2024-03-10 21:42:56  2024-03-10
#             270_078F  2024-03-16 08:54:35  2024-03-16
# 2024-04-03  117_077F  2024-03-31 18:28:01  2024-03-31
#             270_078F  2024-04-06 05:39:40  2024-04-06
# 2024-04-24  117_077F  2024-04-21 15:13:07  2024-04-21
#             270_078F  2024-04-27 02:24:46  2024-04-27
# 2024-06-05  117_077F  2024-06-02 08:43:16  2024-06-02
#             270_078F  2024-06-07 19:54:55  2024-06-07
# 2024-06-25  117_077F  2024-06-23 05:28:20  2024-06-23
#             270_078F  2024-06-28 16:39:59  2024-06-28
# 2024-07-16  117_077F  2024-07-14 02:13:24  2024-07-14
#             270_078F  2024-07-19 13:25:04  2024-07-19
# 2024-08-06  117_077F  2024-08-03 22:58:28  2024-08-03
#             270_078F  2024-08-09 10:10:09  2024-08-09
# 2024-08-27  117_077F  2024-08-24 19:43:32  2024-08-24
#             270_078F  2024-08-30 06:55:13  2024-08-30
# 2024-09-17  117_077F  2024-09-14 16:28:38  2024-09-14
#             270_078F  2024-09-20 03:40:20  2024-09-20
# 2024-10-08  117_077F  2024-10-05 13:13:47  2024-10-05
#             270_078F  2024-10-11 00:25:25  2024-10-11
# 2024-10-29  117_077F  2024-10-26 09:58:50  2024-10-26
#             270_078F  2024-10-31 21:10:29  2024-10-31
# 2024-11-19  117_077F  2024-11-16 06:43:54  2024-11-16
#             270_078F  2024-11-21 17:55:35  2024-11-21
# 2025-01-20  117_077F  2025-01-17 20:59:08  2025-01-17
#             270_078F  2025-01-23 08:10:48  2025-01-23
# 2025-02-10  117_077F  2025-02-07 17:44:11  2025-02-07
#             270_078F  2025-02-13 04:55:51  2025-02-13
# 2025-03-03  117_077F  2025-02-28 14:29:17  2025-02-28
#             270_078F  2025-03-06 01:40:56  2025-03-06
# 2025-03-24  117_077F  2025-03-21 11:14:22  2025-03-21
#             270_078F  2025-03-26 22:26:01  2025-03-26
# 2025-04-14  117_077F  2025-04-11 07:59:26  2025-04-11
#             270_078F  2025-04-16 19:11:06  2025-04-16
# 2025-05-15  117_077F  2025-05-23 01:29:36  2025-05-23
#             270_078F  2025-05-07 15:56:09  2025-05-07
# 2025-06-15  117_077F  2025-06-12 22:14:40  2025-06-12
#             270_078F  2025-06-18 09:26:19  2025-06-18
# 2025-07-06  117_077F  2025-07-03 18:59:47  2025-07-03
#             270_078F  2025-07-09 06:11:27  2025-07-09
# 2025-07-27  117_077F  2025-07-24 15:44:52  2025-07-24
#             270_078F  2025-07-30 02:56:31  2025-07-30
# 2025-08-17  117_077F  2025-08-14 12:29:56  2025-08-14
#             270_078F  2025-08-19 23:41:36  2025-08-19
# 2025-09-07  117_077F  2025-09-04 09:15:00  2025-09-04
#             270_078F  2025-09-09 20:26:40  2025-09-09
# 2025-09-17  117_077F  2025-09-25 06:00:03  2025-09-25
#             270_078F  2025-09-09 20:26:40  2025-09-09
#
#                                                                native-id  \
# mosaic_date tile_name
# 2024-01-11  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_009_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_009_270_...
# 2024-01-31  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_010_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_010_270_...
# 2024-02-21  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_011_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_011_270_...
# 2024-03-13  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_012_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_012_270_...
# 2024-04-03  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_013_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_013_270_...
# 2024-04-24  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_014_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_014_270_...
# 2024-06-05  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_016_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_016_270_...
# 2024-06-25  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_017_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_017_270_...
# 2024-07-16  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_018_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_018_270_...
# 2024-08-06  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_019_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_019_270_...
# 2024-08-27  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_020_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_020_270_...
# 2024-09-17  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_021_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_021_270_...
# 2024-10-08  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_022_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_022_270_...
# 2024-10-29  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_023_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_023_270_...
# 2024-11-19  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_024_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_024_270_...
# 2025-01-20  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_027_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_027_270_...
# 2025-02-10  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_028_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_028_270_...
# 2025-03-03  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_029_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_029_270_...
# 2025-03-24  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_030_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_030_270_...
# 2025-04-14  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_031_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_031_270_...
# 2025-05-15  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_033_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_032_270_...
# 2025-06-15  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_034_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_034_270_...
# 2025-07-06  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_035_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_035_270_...
# 2025-07-27  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_036_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_036_270_...
# 2025-08-17  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_037_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_037_270_...
# 2025-09-07  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_038_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_038_270_...
# 2025-09-17  117_077F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_039_117_...
#             270_078F   SWOT_L2_HR_Raster_100m_UTM20M_N_x_x_x_038_270_...
#
#                                                                      url
# mosaic_date tile_name
# 2024-01-11  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-01-31  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-02-21  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-03-13  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-04-03  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-04-24  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-06-05  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-06-25  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-07-16  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-08-06  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-08-27  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-09-17  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-10-08  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-10-29  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2024-11-19  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-01-20  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-02-10  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-03-03  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-03-24  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-04-14  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-05-15  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-06-15  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-07-06  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-07-27  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-08-17  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-09-07  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
# 2025-09-17  117_077F   https://archive.swot.podaac.earthdata.nasa.gov...
#             270_078F   https://archive.swot.podaac.earthdata.nasa.gov...
